# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\user\\Downloads\\NIFTY 50-01-07-2024-to-01-07-2025.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  01-JUL-2024  23992.95  24164.00  23992.70  24141.95     242468081.0
# 1  02-JUL-2024  24228.75  24236.35  24056.40  24123.85     309629240.0
# 2  03-JUL-2024  24291.75  24309.15  24207.10  24286.50     289201551.0
# 3  04-JUL-2024  24369.95  24401.00  24281.00  24302.15     251189844.0
# 4  05-JUL-2024  24213.35  24363.00  24168.85  24323.85     298381204.0
#
#    Turnover (₹ Cr)
# 0         28204.06
# 1         34838.65
# 2         36661.17
# 3         28466.60
# 4         32052.48

# %%
df.tail()
# Out:
#            Date      Open      High       Low     Close   Shares Traded   \
# 244  24-JUN-2025  25179.90  25317.70  24999.70  25044.35     450185468.0
# 245  25-JUN-2025  25150.35  25266.80  25125.05  25244.75     260582584.0
# 246  26-JUN-2025  25268.95  25565.30  25259.90  25549.00     428891818.0
# 247  27-JUN-2025  25576.65  25654.20  25523.55  25637.80     563957748.0
# 248  30-JUN-2025  25661.65  25669.35  25473.30  25517.05     270981274.0
#
#      Turnover (₹ Cr)
# 244         35508.90
# 245         22985.17
# 246         38689.39
# 247         47108.60
# 248         24673.48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             249 non-null    object
#  1   Open             249 non-null    float64
#  2   High             249 non-null    float64
#  3   Low              249 non-null    float64
#  4   Close            249 non-null    float64
#  5   Shares Traded    248 non-null    float64
#  6   Turnover (₹ Cr)  248 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.7+ KB

# %%
df.shape
# Out:
# (249, 7)

# %%
df.dtypes
# Out:
# Date                object
# Open               float64
# High               float64
# Low                float64
# Close              float64
# Shares Traded      float64
# Turnover (₹ Cr)    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (₹ Cr)'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=249, step=1)

# %%
df.isnull()
# Out:
#      Date   Open   High    Low   Close   Shares Traded   Turnover (₹ Cr)
# 0    False  False  False  False   False           False            False
# 1    False  False  False  False   False           False            False
# 2    False  False  False  False   False           False            False
# 3    False  False  False  False   False           False            False
# 4    False  False  False  False   False           False            False
# ..     ...    ...    ...    ...     ...             ...              ...
# 244  False  False  False  False   False           False            False
# 245  False  False  False  False   False           False            False
# 246  False  False  False  False   False           False            False
# 247  False  False  False  False   False           False            False
# 248  False  False  False  False   False           False            False
#
# [249 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Shares Traded      1
# Turnover (₹ Cr)    1
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# Length: 249, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Date               249
# Open               249
# High               248
# Low                249
# Close              249
# Shares Traded      248
# Turnover (₹ Cr)    248
# dtype: int64

# %%
df.value_counts()
# Out:
# Date         Open      High      Low       Close     Shares Traded   Turnover (₹ Cr)
# 01-APR-2025  23341.10  23565.15  23136.40  23165.70  375118343.0     30680.70           1
# 22-APR-2025  24185.40  24242.60  24072.00  24167.25  440940490.0     35479.29           1
# 20-JAN-2025  23290.40  23391.10  23170.65  23344.75  301455455.0     27333.97           1
# 20-JUN-2025  24787.65  25136.20  24783.65  25112.40  574654035.0     55782.03           1
# 20-MAR-2025  23036.60  23216.70  22973.95  23190.65  313729818.0     27573.99           1
#                                                                                        ..
# 11-JUN-2025  25134.15  25222.40  25081.30  25141.40  301245273.0     25871.18           1
# 11-MAR-2025  22345.95  22522.10  22314.70  22497.90  347924102.0     29208.22           1
# 11-NOV-2024  24087.25  24336.80  24004.60  24141.30  273370562.0     26600.28           1
# ...

# %%
df.empty
# Out:
# False

# %%
df.describe(include = 'all')
# Out:
#               Date          Open          High           Low         Close   \
# count           249    249.000000    249.000000    249.000000    249.000000
# unique          249           NaN           NaN           NaN           NaN
# top     01-JUL-2024           NaN           NaN           NaN           NaN
# freq              1           NaN           NaN           NaN           NaN
# mean            NaN  24195.175904  24311.198996  24066.315863  24190.033333
# std             NaN    883.274736    875.014331    886.520790    880.178370
# min             NaN  21758.400000  22105.050000  21743.650000  22082.650000
# 25%             NaN  23543.800000  23689.850000  23433.500000  23532.700000
# 50%             NaN  24342.350000  24440.250000  24198.750000  24328.950000
# 75%             NaN  24832.200000  24967.100000  24704.100000  24833.600000
# max             NaN  26248.250000  26277.350000  26151.400000  26216.050000
#
#         Shares Traded   Turnover (₹ Cr)
# ...

# %% [markdown]
# # open
# 1. count = 249 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24,195
# 3. std = price fluctuated with opening of market
# 4. min = the lowest price in the total days
# 5. 25% = 25% of day the market open nearby 	23543
# 6. 50% = 50% of day the market open nearby 24342
# 7. 75% = 75% of day the market open nearby 	24832
# 8. max = highest price among all days

# %% [markdown]
# # High
#
# 1. count = 249 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24311
# 3. std = price fluctuated with opening of market 875
# 4. min = the lowest price in the total days
# 5. 25% = 25% of day the market was  nearby 22101
# 6. 50% = 50% of day the market was  nearby 24440
# 7. 75% = 75% of day the market was nearby 24967
# 8. max = highest price among all days, 26277

# %% [markdown]
# # Low
# 1. count = 249 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24311
# 3. std = price fluctuated with opening of market 886
# 4. min = the lowest price in the total days 21743
# 5. 25% = 25% of day the market low nearby 23433
# 6. 50% = 50% of day the market low nearby 24198.
# 7. 75% = 75% of day the market low nearby 24704
# 8. max = highest price among all days 26151

# %% [markdown]
# # Close
# 1. count = 249 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24,190
# 3. std = price fluctuated with opening of market
# 4. min = the lowest price in the total days
# 5. 25% = 25% of day the market close nearby 23532
# 6. 50% = 50% of day the market close nearby 24328
# 7. 75% = 75% of day the market close nearby 24833
# 8. max = highest price among all days

# %% [markdown]
# # Shares Traded
# 1. count = Data available for 248 days (1 day missing).
# 2. mean = On average, 3 crore shares were traded daily
# 3. std = price fluctuated with opening of market
# 4. min = the lowest price in the total days
# 5. 25% = 25% of days the market has shared trades nearby 2.567921e+08
# 6. 50% = 50% of days the market has shared trades nearby 2.985532e+08
# 7. 75% = 75% of days the market has shared trades nearby 	3.626338e+08
# 8. max = highest price among all days

# %% [markdown]
# # 		Turnover
# 1. count = Data available for 248 days (1 day missing).
# 2. mean = On average, 3 crore shares were traded daily
# 3. std = price fluctuated with opening of market
# 4. min = the lowest price in the total days
# 5. 25% = 25% of days the market has Turnover 25160.
# 6. 50% = 50% of days the market has Turnover 28851.
# 7. 75% = 75% of days the market has Turnover 33878
# 8. max = highest price among all day

# %%
df.dropna(subset= ["Shares Traded" and "Turnover (₹ Cr)"],inplace = True)

# %%
df.isnull().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Shares Traded      0
# Turnover (₹ Cr)    0
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#               Date          Open          High           Low         Close   \
# count           248    248.000000    248.000000    248.000000    248.000000
# unique          248           NaN           NaN           NaN           NaN
# top     01-JUL-2024           NaN           NaN           NaN           NaN
# freq              1           NaN           NaN           NaN           NaN
# mean            NaN  24192.520161  24309.007056  24064.534274  24188.658871
# std             NaN    884.064229    876.098561    887.866786    881.690509
# min             NaN  21758.400000  22105.050000  21743.650000  22082.650000
# 25%             NaN  23543.387500  23689.762500  23430.912500  23531.150000
# 50%             NaN  24342.200000  24433.200000  24196.250000  24328.725000
# 75%             NaN  24826.875000  24968.262500  24707.425000  24833.912500
# max             NaN  26248.250000  26277.350000  26151.400000  26216.050000
#
#         Shares Traded   Turnover (₹ Cr)
# ...

# %% [markdown]
# # open
# 1. count = 248 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24,195(remain same)
# 3. std = price fluctuated with opening of market
# 4. min = the lowest price in the total days
# 5. % = 25% of day the market open nearby 23543
# 6. 50% = 50% of day the market open nearby 24342
# 7. 75% = 75% of day the market open nearby 24826(changed a bit)
# 8. max = highest price among all days

# %% [markdown]
# # High
# 1. count = 248 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24311(changed by 24309)
# 3. std = price fluctuated with opening of market 875
# 4. min = the lowest price in the total days
# 5. 25% = 25% of day the market was nearby 22101(changed by 23689)
# 6. 50% = 50% of day the market was nearby 24440(changed by 24433)
# 8. 75% = 75% of day the market was nearby 24967(changed by 24968)
# 9. max = highest price among all days, 26277

# %% [markdown]
# # Low
# 1. count = 248 days for trade in market
# 2. mean = value is evenly distributed . on avrage the market opend at 24064
# 3. std = price fluctuated with opening of market 887
# 4. min = the lowest price in the total days 21743(same)
# 5. 25% = 25% of day the market low nearby 23433(23430.)
# 6. 50% = 50% of day the market low nearby 24198.(24196)
# 7. 75% = 75% of day the market low nearby 24704(24707)
# 8. max = highest price among all days 26151(26151)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 248 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             248 non-null    object
#  1   Open             248 non-null    float64
#  2   High             248 non-null    float64
#  3   Low              248 non-null    float64
#  4   Close            248 non-null    float64
#  5   Shares Traded    248 non-null    float64
#  6   Turnover (₹ Cr)  248 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 15.5+ KB

# %%
df = pd.read_csv("C:\\Users\\user\\Downloads\\NIFTY 50-01-07-2024-to-01-07-2025.csv")

# %%
print(df.columns.tolist())
print(df.head())
# Out:
# ['Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ', 'Turnover (₹ Cr)']
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  01-JUL-2024  23992.95  24164.00  23992.70  24141.95     242468081.0
# 1  02-JUL-2024  24228.75  24236.35  24056.40  24123.85     309629240.0
# 2  03-JUL-2024  24291.75  24309.15  24207.10  24286.50     289201551.0
# 3  04-JUL-2024  24369.95  24401.00  24281.00  24302.15     251189844.0
# 4  05-JUL-2024  24213.35  24363.00  24168.85  24323.85     298381204.0
#
#    Turnover (₹ Cr)
# 0         28204.06
# 1         34838.65
# 2         36661.17
# 3         28466.60
# 4         32052.48

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2168\2263964175.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df = df.set_index('Date').sort_index()

# %%
print(df.head())
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2024-07-01  23992.95  24164.00  23992.70  24141.95    242468081.0
# 2024-07-02  24228.75  24236.35  24056.40  24123.85    309629240.0
# 2024-07-03  24291.75  24309.15  24207.10  24286.50    289201551.0
# 2024-07-04  24369.95  24401.00  24281.00  24302.15    251189844.0
# 2024-07-05  24213.35  24363.00  24168.85  24323.85    298381204.0
#
#             Turnover (₹ Cr)
# Date
# 2024-07-01         28204.06
# 2024-07-02         34838.65
# 2024-07-03         36661.17
# 2024-07-04         28466.60
# 2024-07-05         32052.48

# %%
df['Open'].rolling(window='30D').mean()
# Out:
# Date
# 2024-07-01    23992.950000
# 2024-07-02    24110.850000
# 2024-07-03    24171.150000
# 2024-07-04    24220.850000
# 2024-07-05    24219.350000
#                   ...
# 2025-06-24    24869.972727
# 2025-06-25    24880.472727
# 2025-06-26    24894.668182
# 2025-06-27    24928.493182
# 2025-06-30    24973.847619
# Name: Open, Length: 249, dtype: float64

# %%
df['Open'].rolling('30D').mean().plot(title='30-Day Moving Average of open')
# Out:
# <Axes: title={'center': '30-Day Moving Average of open'}, xlabel='Date'>

# %%
df['High'].rolling(window='30D').mean()
# Out:
# Date
# 2024-07-01    24164.000000
# 2024-07-02    24200.175000
# 2024-07-03    24236.500000
# 2024-07-04    24277.625000
# 2024-07-05    24294.700000
#                   ...
# 2025-06-24    24988.138636
# 2025-06-25    24996.665909
# 2025-06-26    25019.502273
# 2025-06-27    25055.409091
# 2025-06-30    25101.514286
# Name: High, Length: 249, dtype: float64

# %%
df['High'].rolling('30D').mean().plot(title='30-Day Moving Average of High')
# Out:
# <Axes: title={'center': '30-Day Moving Average of High'}, xlabel='Date'>

# %%
df['Low'].rolling(window='30D').mean()
# Out:
# Date
# 2024-07-01    23992.700000
# 2024-07-02    24024.550000
# 2024-07-03    24085.400000
# 2024-07-04    24134.300000
# 2024-07-05    24141.210000
#                   ...
# 2025-06-24    24759.172727
# 2025-06-25    24769.379545
# 2025-06-26    24794.643182
# 2025-06-27    24830.393182
# 2025-06-30    24873.678571
# Name: Low, Length: 249, dtype: float64

# %%
df['Low'].rolling('30D').mean().plot(title='30-Day Moving Average of Low')
# Out:
# <Axes: title={'center': '30-Day Moving Average of Low'}, xlabel='Date'>

# %%
df['Close'].rolling(window='30D').mean()
# Out:
# Date
# 2024-07-01    24141.950000
# 2024-07-02    24132.900000
# 2024-07-03    24184.100000
# 2024-07-04    24213.612500
# 2024-07-05    24235.660000
#                   ...
# 2025-06-24    24876.675000
# 2025-06-25    24887.747727
# 2025-06-26    24920.602273
# 2025-06-27    24960.845455
# 2025-06-30    25003.397619
# Name: Close, Length: 249, dtype: float64

# %%
df['Close'].rolling('30D').mean().plot(title='30-Day Moving Average of Close')
# Out:
# <Axes: title={'center': '30-Day Moving Average of Close'}, xlabel='Date'>

# %%
df['Open'].rolling(window='90D').mean()
# Out:
# Date
# 2024-07-01    23992.950000
# 2024-07-02    24110.850000
# 2024-07-03    24171.150000
# 2024-07-04    24220.850000
# 2024-07-05    24219.350000
#                   ...
# 2025-06-24    24304.650000
# 2025-06-25    24333.741525
# 2025-06-26    24362.022034
# 2025-06-27    24382.265833
# 2025-06-30    24420.941667
# Name: Open, Length: 249, dtype: float64

# %%
df['Open'].rolling('90D').mean().plot(title='90-Day Moving Average of open')
# Out:
# <Axes: title={'center': '90-Day Moving Average of open'}, xlabel='Date'>

# %%
df['Close'].rolling(window='90D').mean()
# Out:
# Date
# 2024-07-01    24141.950000
# 2024-07-02    24132.900000
# 2024-07-03    24184.100000
# 2024-07-04    24213.612500
# 2024-07-05    24235.660000
#                   ...
# 2025-06-24    24331.201695
# 2025-06-25    24359.215254
# 2025-06-26    24393.616102
# 2025-06-27    24414.352500
# 2025-06-30    24453.541667
# Name: Close, Length: 249, dtype: float64

# %%
df['Close'].rolling('90D').mean().plot(title='90-Day Moving Average of Close')
# Out:
# <Axes: title={'center': '90-Day Moving Average of Close'}, xlabel='Date'>

# %%
df['High'].rolling(window='90D').mean()
# Out:
# Date
# 2024-07-01    24164.000000
# 2024-07-02    24200.175000
# 2024-07-03    24236.500000
# 2024-07-04    24277.625000
# 2024-07-05    24294.700000
#                   ...
# 2025-06-24    24448.239831
# 2025-06-25    24475.703390
# 2025-06-26    24508.179661
# 2025-06-27    24527.280000
# 2025-06-30    24562.350000
# Name: High, Length: 249, dtype: float64

# %%
df['High'].rolling('90D').mean().plot(title='90-Day Moving Average of High')
# Out:
# <Axes: title={'center': '90-Day Moving Average of High'}, xlabel='Date'>

# %%
df['Low'].rolling(window='90D').mean()
# Out:
# Date
# 2024-07-01    23992.700000
# 2024-07-02    24024.550000
# 2024-07-03    24085.400000
# 2024-07-04    24134.300000
# 2024-07-05    24141.210000
#                   ...
# 2025-06-24    24185.451695
# 2025-06-25    24214.483051
# 2025-06-26    24245.155932
# 2025-06-27    24266.462500
# 2025-06-30    24305.410833
# Name: Low, Length: 249, dtype: float64

# %%
df['Low'].rolling('90D').mean().plot(title='90-Day Moving Average of Low')
# Out:
# <Axes: title={'center': '90-Day Moving Average of Low'}, xlabel='Date'>

# %%
df['log_return'] = np.log(df['Close']).diff()

# %%
df['log_return']
# Out:
# Date
# 2024-07-01         NaN
# 2024-07-02   -0.000750
# 2024-07-03    0.006720
# 2024-07-04    0.000644
# 2024-07-05    0.000893
#                 ...
# 2025-06-24    0.002897
# 2025-06-25    0.007970
# 2025-06-26    0.011980
# 2025-06-27    0.003470
# 2025-06-30   -0.004721
# Name: log_return, Length: 248, dtype: float64

# %%
df.dropna(inplace= True)

# %%
pip install statsmodels
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from statsmodels.tsa.stattools import adfuller # stationary test using augmented dicky-fuller . it'll test null hypothesis

# %%
adfuller(df['Close'])
# Out:
# (-1.5322674706947457,
#  0.5174930114209756,
#  0,
#  246,
#  {'1%': -3.457215237265747,
#   '5%': -2.873361841566324,
#   '10%': -2.5730700760129555},
#  3112.8944149297645)

# %%
adfuller(df['log_return'])
# Out:
# (-15.267875602189394,
#  4.761630199504404e-28,
#  0,
#  246,
#  {'1%': -3.457215237265747,
#   '5%': -2.873361841566324,
#   '10%': -2.5730700760129555},
#  -1524.0938986843407)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt .figure() 
df['Close'].hist(bins = 10)
plt.title("Distribution of close feature")
plt.xlabel("Close price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.boxplot(y= df["Close"])
plt.title("Box plot for close price")
plt.show()

# %%
# BIVARIATE
#scatter plot

plt.figure()
plt.scatter(df["Open"],df["Close"])
plt.title("Open vs close price")
plt.xlabel("Open")
plt.ylabel("Close")
plt.show()

# %%
#correlation 
plt.figure()
corr = df[['Open','Close','High','Low']].corr()
print(corr)

sns.heatmap(corr, annot = True, cmap ="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#            Open     Close      High       Low
# Open   1.000000  0.983024  0.992818  0.992558
# Close  0.983024  1.000000  0.993015  0.992036
# High   0.992818  0.993015  1.000000  0.991190
# Low    0.992558  0.992036  0.991190  1.000000

# %%
df.dropna(inplace = True)

# %%
df['mac_30']= df['Close'].rolling(window = 30 ).mean()

# %%
df['mac_30']= df['Close'].rolling(window = 30 ).mean()

# %%
df.describe()
# Out:
#                Open          High           Low         Close  Shares Traded  \
# count    247.000000    247.000000    247.000000    247.000000   2.470000e+02
# mean   24193.328138  24309.594130  24064.825101  24188.847976   3.179927e+08
# std      885.767528    877.828562    889.657726    883.475706   9.817753e+07
# min    21758.400000  22105.050000  21743.650000  22082.650000   3.881139e+07
# 25%    23542.975000  23689.675000  23428.325000  23529.600000   2.571715e+08
# 50%    24342.350000  24440.250000  24198.750000  24328.950000   2.987251e+08
# 75%    24828.650000  24969.425000  24710.750000  24834.225000   3.633990e+08
# max    26248.250000  26277.350000  26151.400000  26216.050000   8.538910e+08
#
#        Turnover (₹ Cr)  log_return        mac_30
# count       247.000000  247.000000    218.000000
# mean      30513.072024    0.000224  24114.089098
# std        9420.905211    0.008603    786.056151
# min        3348.450000   -0.032970  22773.135000
# ...

# %%
plt.plot(df['Open'], color='purple')
plt.title("Line Plot of Open Prices")
plt.xlabel("Index")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# here the graph shows the highet point of the opening price is near 26,000 which means according to graph the highest price reached in between 2024-09 to 24-11 and the lowest was near or below 22000 there is significant volatility in the open price .

# %%
plt.violinplot(df['High'])
plt.title("Line Plot of High Prices")
plt.xlabel("Index")
plt.ylabel("High Price")
plt.show()

# %% [markdown]
# there is bulge in the range 24000 to 25000 that means the highest price was near to that range ...

# %%
df['mac_30'].plot.kde()
plt.title("MAC 30 KDE Plot")
plt.show()

# %% [markdown]
# Even in the 30 day average, the price was fluctuating significantly. The highest was near 25,000 and after that, the graph started sliding down.

# %%
df['log_return'].hist(bins=30, color='hotpink')
plt.title("Distribution of Log Returns")
plt.show()

# %%
df.boxplot(column='Turnover (₹ Cr)')
plt.title("Boxplot of Turnover")
plt.show()

# %% [markdown]
# trunover is basically the profit of the user , The boxplot shows that most turnover values are clustered between
# ₹20,000 and ₹40,000 , with several high-value outliers above ₹60,000 .

# %%
plt.scatter(df['Turnover (₹ Cr)'], df['Shares Traded'])
plt.xlabel("Turnover")
plt.ylabel("Shares Traded")
plt.title("Turnover vs Shares Traded")
plt.show()

# %% [markdown]
# trunover is basically the profit of the user , The boxplot shows that most turnover values are clustered between
# ₹20,000 and ₹40,000 , with several high-value outliers above ₹60,000 .

# %%
plt.scatter(df['Turnover (₹ Cr)'], df['Open'], color='red', label='Open')
plt.scatter(df['Turnover (₹ Cr)'], df['Close'], color='blue', label='Close')
plt.scatter(df['Turnover (₹ Cr)'], df['High'], color='green', label='High')
plt.scatter(df['Turnover (₹ Cr)'], df['Low'], color='magenta',label = 'Low')

plt.xlabel("Turnover (₹ Cr)")
plt.ylabel("Price")
plt.title("Turnover vs Various Prices")
plt.legend()
plt.show()

# %% [markdown]
# this is multivariate anlaysis of the trunover with all the high, low, open ,close factors and in this graph show there is
# compact cluster on range 24,000 and 25,000 that means most of the values revolve around the same .

# %%
sns.jointplot(x='Open', y='Close', data=df, kind='scatter')

# %%
this is bivariate anlaysis of open ,close factors and in this graph show there is compact cluster on
range 24,000 and 25,000 that means most of the values revolve around the same .
